# %% [markdown]
# ## Linear Regression : Sample Notebook

# %% [markdown]
# Loading required libraries and setting plot params

# %%
# %matplotlib inline
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import statsmodels.api as sm

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)
plt.xkcd()

# %% [markdown]
# ### Load and View Data

# %%
df = pd.DataFrame.from_csv(r'data\student_height_weight.csv',
                           index_col=None)

# %%
df.head()
# Out:
#    height  weight
# 0      63     127
# 1      64     121
# 2      66     142
# 3      69     157
# 4      69     162

# %% [markdown]
# ### Visualize the data frame

# %%
fig = plt.figure(figsize=(20,10))

ax = fig.add_subplot(1, 1, 1)
plt.scatter(df.height,df.weight)
ax.set_title('Height Vs Weight')
ax.set_xlabel('Height')
ax.set_ylabel('Weight')

# %% [markdown]
# ### Build a OLS Regression Model

# %%
# Set the independent variable
X = df1.height.values.tolist()

# This handles the intercept. 
# Statsmodel takes 0 intercept by default
X = sm.add_constant(X)

# Set the dependent variable
y = df1.weight

# Build OLS model
model = sm.OLS(y, X)
results = model.fit()

# Get the predicted values for dependent variable
pred_y = results.predict(X)

# View Model stats
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 weight   R-squared:                       0.756
# Model:                            OLS   Adj. R-squared:                  0.743
# Method:                 Least Squares   F-statistic:                     55.82
# Date:                Sun, 27 Nov 2016   Prob (F-statistic):           6.40e-07
# Time:                        15:41:29   Log-Likelihood:                -71.910
# No. Observations:                  20   AIC:                             147.8
# Df Residuals:                      18   BIC:                             149.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        -53.0759     27.720     -1.915      0.072      -111.314     5.162
# x1             2.9845      0.399      7.471      0.000         2.145     3.824
# ==============================================================================
# Omnibus:                        0.353   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.838   Jarque-Bera (JB):                0.503
# Skew:                           0.128   Prob(JB):                        0.778
# Kurtosis:                       2.267   Cond. No.                         926.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Model Analysis
#
# Model Summary:
# * The above results present an intercept of -53.0759 and a slope of 2.9845
# * A positive slope shows an upward trend (as expected from the scatter plot above)
# * R² of 0.756 points towards a good enough model

# %% [markdown]
# ### Visualize
#
# * Plot the data points
# * Plot the regression line (red)
# * Plot the mean line (black). _See regression part ii for reference_.

# %%
fig = plt.figure(figsize=(20,10))
# set the canvas
ax = fig.add_subplot(1, 1, 1)
ax.set_title('Height Vs Weight')
ax.set_xlabel('Height')
ax.set_ylabel('Weight')

# plot the data points
plt.scatter(df1.height,df1.weight)

# plot the regression line
plt.plot(df1.height,pred_y,color='red')

# plot the mean line
plt.plot(df1.height,
         [df1.weight.mean()]*df1.weight.count(),
         color='black')

# display the legent
plt.legend()
